# %% [markdown]
# # Master's thesis - Lukas Meuris - graphCast evaluation
#
# This notebook contains the code to evaluate the models.

# %%
#!pip install git+https://github.com/google-research/weatherbench2.git
# Out:
# Collecting git+https://github.com/google-research/weatherbench2.git
#   Cloning https://github.com/google-research/weatherbench2.git to c:\users\lukas\appdata\local\temp\pip-req-build-nx0j_vv6
#   Resolved https://github.com/google-research/weatherbench2.git to commit c6c4a1ad6f596714051be544bd0e955f8cc4ff6d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting apache-beam>=2.31.0 (from weatherbench2==0.2.0)
#   Downloading apache_beam-2.55.1-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: jax[cpu] in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from weatherbench2==0.2.0) (0.4.26)
# Requirement already satisfied: numpy in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from weatherbench2==0.2.0) (1.26.4)
# Collecting pandas==2.0.3 (from weatherbench2==0.2.0)
#   Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: scipy in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from weatherbench2==0.2.0) (1.13.0)
# Collecting scikit-learn (from weatherbench2==0.2.0)
#   Downloading scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting xarray==2023.7.0 (from weatherbench2==0.2.0)
#   Downloading xarray-2023.7.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting xarray-beam (from weatherbench2==0.2.0)
#   Downloading xarray_beam-0.6.3-py3-none-any.whl.metadata (849 bytes)
# Collecting zarr (from weatherbench2==0.2.0)
#   Downloading zarr-2.17.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from pandas==2.0.3->weatherbench2==0.2.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from pandas==2.0.3->weatherbench2==0.2.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from pandas==2.0.3->weatherbench2==0.2.0) (2024.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from xarray==2023.7.0->weatherbench2==0.2.0) (23.2)
# Collecting crcmod<2.0,>=1.7 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ---------------------------------------- 0.0/89.7 kB ? eta -:--:--
#      ---------------------- ----------------- 51.2/89.7 kB 2.6 MB/s eta 0:00:01
#      ---------------------------------------- 89.7/89.7 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting orjson<4,>=3.9.7 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading orjson-3.10.1-cp311-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#      ------------------------ --------------- 30.7/50.9 kB ? eta -:--:--
#      ------------------------ --------------- 30.7/50.9 kB ? eta -:--:--
#      ------------------------ --------------- 30.7/50.9 kB ? eta -:--:--
#      ------------------------ --------------- 30.7/50.9 kB ? eta -:--:--
#      -------------------------------------- 50.9/50.9 kB 217.4 kB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ---------------------------------------- 0.0/152.0 kB ? eta -:--:--
#      --------------- ----------------------- 61.4/152.0 kB 3.4 MB/s eta 0:00:01
#      -------------------------------------- 152.0/152.0 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cloudpickle~=2.2.1 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting fastavro<2,>=0.23.6 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading fastavro-1.9.4-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# Collecting fasteners<1.0,>=0.3 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting grpcio!=1.48.0,<2,>=1.33.1 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading grpcio-1.62.2-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      ---------------------------------------- 0.0/43.5 kB ? eta -:--:--
#      ---------------------------------------- 43.5/43.5 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting httplib2<0.23.0,>=0.8 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting js2py<1,>=0.74 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading Js2Py-0.74-py3-none-any.whl.metadata (868 bytes)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from apache-beam>=2.31.0->weatherbench2==0.2.0) (4.19.2)
# Collecting jsonpickle<4.0.0,>=3.0.0 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading jsonpickle-3.0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting objsize<0.8.0,>=0.6.1 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading objsize-0.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading pymongo-4.7.0-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Collecting proto-plus<2,>=1.7.1 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Using cached proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting pydot<2,>=1.2.0 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading pydot-1.4.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting regex>=2020.6.8 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading regex-2024.4.16-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from apache-beam>=2.31.0->weatherbench2==0.2.0) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from apache-beam>=2.31.0->weatherbench2==0.2.0) (4.9.0)
# Collecting zstandard<1,>=0.18.0 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading zstandard-0.22.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting pyarrow<12.0.0,>=3.0.0 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading pyarrow-11.0.0-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting pyarrow-hotfix<1 (from apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from jax[cpu]->weatherbench2==0.2.0) (0.4.0)
# Requirement already satisfied: opt-einsum in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from jax[cpu]->weatherbench2==0.2.0) (3.3.0)
# Requirement already satisfied: jaxlib==0.4.26 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from jax[cpu]->weatherbench2==0.2.0) (0.4.26)
# Collecting joblib>=1.2.0 (from scikit-learn->weatherbench2==0.2.0)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->weatherbench2==0.2.0)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: dask in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from xarray-beam->weatherbench2==0.2.0) (2024.4.2)
# Collecting immutabledict (from xarray-beam->weatherbench2==0.2.0)
#   Downloading immutabledict-4.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rechunker>=0.5.1 (from xarray-beam->weatherbench2==0.2.0)
#   Downloading rechunker-0.5.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting asciitree (from zarr->weatherbench2==0.2.0)
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting numcodecs>=0.10.0 (from zarr->weatherbench2==0.2.0)
#   Downloading numcodecs-0.12.1-cp311-cp311-win_amd64.whl.metadata (2.9 kB)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six>=1.9.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from httplib2<0.23.0,>=0.8->apache-beam>=2.31.0->weatherbench2==0.2.0) (3.1.2)
# Collecting tzlocal>=1.2 (from js2py<1,>=0.74->apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting pyjsparser>=2.5.1 (from js2py<1,>=0.74->apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (0.10.6)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam>=2.31.0->weatherbench2==0.2.0)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting mypy-extensions (from rechunker>=0.5.1->xarray-beam->weatherbench2==0.2.0)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from requests<3.0.0,>=2.24.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from requests<3.0.0,>=2.24.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from requests<3.0.0,>=2.24.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from requests<3.0.0,>=2.24.0->apache-beam>=2.31.0->weatherbench2==0.2.0) (2024.2.2)
# Requirement already satisfied: click>=8.1 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from dask->xarray-beam->weatherbench2==0.2.0) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from dask->xarray-beam->weatherbench2==0.2.0) (2024.3.1)
# Requirement already satisfied: partd>=1.2.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from dask->xarray-beam->weatherbench2==0.2.0) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from dask->xarray-beam->weatherbench2==0.2.0) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from dask->xarray-beam->weatherbench2==0.2.0) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from dask->xarray-beam->weatherbench2==0.2.0) (7.1.0)
# Requirement already satisfied: colorama in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from click>=8.1->dask->xarray-beam->weatherbench2==0.2.0) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from importlib-metadata>=4.13.0->dask->xarray-beam->weatherbench2==0.2.0) (3.18.1)
# Requirement already satisfied: locket in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from partd>=1.2.0->dask->xarray-beam->weatherbench2==0.2.0) (1.0.0)
# Collecting bokeh>=2.4.2 (from dask[array,diagnostics]->rechunker>=0.5.1->xarray-beam->weatherbench2==0.2.0)
#   Downloading bokeh-3.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from dask[array,diagnostics]->rechunker>=0.5.1->xarray-beam->weatherbench2==0.2.0) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from bokeh>=2.4.2->dask[array,diagnostics]->rechunker>=0.5.1->xarray-beam->weatherbench2==0.2.0) (1.2.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from bokeh>=2.4.2->dask[array,diagnostics]->rechunker>=0.5.1->xarray-beam->weatherbench2==0.2.0) (10.3.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from bokeh>=2.4.2->dask[array,diagnostics]->rechunker>=0.5.1->xarray-beam->weatherbench2==0.2.0) (6.3.3)
# Collecting xyzservices>=2021.09.1 (from bokeh>=2.4.2->dask[array,diagnostics]->rechunker>=0.5.1->xarray-beam->weatherbench2==0.2.0)
#   Downloading xyzservices-2024.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lukas\anaconda3\envs\mtlmenv\lib\site-packages (from jinja2>=2.10.3->dask[array,diagnostics]->rechunker>=0.5.1->xarray-beam->weatherbench2==0.2.0) (2.1.3)
# Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.6 MB 5.1 MB/s eta 0:00:03
#     --------------------------------------- 0.2/10.6 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/10.6 MB 2.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/10.6 MB 2.1 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/10.6 MB 2.1 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/10.6 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/10.6 MB 2.0 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/10.6 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/10.6 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/10.6 MB 2.2 MB/s eta 0:00:05
#    --- ------------------------------------ 1.1/10.6 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.2/10.6 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/10.6 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.4/10.6 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.5/10.6 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.6 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.7/10.6 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/10.6 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 2.0/10.6 MB 2.3 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/10.6 MB 2.3 MB/s eta 0:00:04
#    -------- ------------------------------- 2.2/10.6 MB 2.3 MB/s eta 0:00:04
#    -------- ------------------------------- 2.2/10.6 MB 2.2 MB/s eta 0:00:04
#    -------- ------------------------------- 2.3/10.6 MB 2.2 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/10.6 MB 2.2 MB/s eta 0:00:04
#    --------- ------------------------------ 2.5/10.6 MB 2.2 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/10.6 MB 2.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.7/10.6 MB 2.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.8/10.6 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/10.6 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/10.6 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.2/10.6 MB 2.2 MB/s eta 0:00:04
#    ------------ --------------------------- 3.3/10.6 MB 2.2 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/10.6 MB 2.2 MB/s eta 0:00:04
#    ------------- -------------------------- 3.5/10.6 MB 2.2 MB/s eta 0:00:04
#    ------------- -------------------------- 3.6/10.6 MB 2.2 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/10.6 MB 2.2 MB/s eta 0:00:04
#    -------------- ------------------------- 3.8/10.6 MB 2.2 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/10.6 MB 2.2 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/10.6 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.0/10.6 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.1/10.6 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/10.6 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.3/10.6 MB 2.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.4/10.6 MB 2.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/10.6 MB 2.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.6/10.6 MB 2.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/10.6 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 4.8/10.6 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 4.9/10.6 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.1/10.6 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.2/10.6 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.3/10.6 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.4/10.6 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.4/10.6 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/10.6 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 5.6/10.6 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 5.7/10.6 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 5.8/10.6 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 5.8/10.6 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.9/10.6 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.0/10.6 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.1/10.6 MB 2.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.2/10.6 MB 2.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.3/10.6 MB 2.1 MB/s eta 0:00:03
#    ------------------------ --------------- 6.4/10.6 MB 2.1 MB/s eta 0:00:03
#    ------------------------ --------------- 6.5/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.6/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.7/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.8/10.6 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 6.9/10.6 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 7.0/10.6 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.6 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 7.2/10.6 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 7.3/10.6 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 7.4/10.6 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.5/10.6 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.6/10.6 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.7/10.6 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.8/10.6 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.9/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 8.0/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 8.1/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 8.2/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 8.3/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 8.4/10.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 8.5/10.6 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 8.6/10.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.6/10.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.8/10.6 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.8/10.6 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.6 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 9.0/10.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.1/10.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.3/10.6 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.5/10.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.6/10.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.6/10.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.8/10.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.9/10.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 10.1/10.6 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 10.2/10.6 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 2.0 MB/s eta 0:00:00
# Downloading xarray-2023.7.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.0 MB 2.0 MB/s eta 0:00:01
#    ------- -------------------------------- 0.2/1.0 MB 2.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.3/1.0 MB 2.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.4/1.0 MB 2.3 MB/s eta 0:00:01
#    -------------------- ------------------- 0.5/1.0 MB 2.3 MB/s eta 0:00:01
#    ------------------------ --------------- 0.6/1.0 MB 2.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.7/1.0 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 0.8/1.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 0.9/1.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 1.0/1.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.1 MB/s eta 0:00:00
# Downloading apache_beam-2.55.1-cp311-cp311-win_amd64.whl (5.1 MB)
#    ---------------------------------------- 0.0/5.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/5.1 MB 1.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.1/5.1 MB 2.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.3/5.1 MB 2.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.3/5.1 MB 2.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.5/5.1 MB 2.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.6/5.1 MB 2.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.6/5.1 MB 2.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.7/5.1 MB 2.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.8/5.1 MB 1.8 MB/s eta 0:00:03
#    ------ --------------------------------- 0.8/5.1 MB 1.8 MB/s eta 0:00:03
#    ------- -------------------------------- 0.9/5.1 MB 1.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.0/5.1 MB 1.8 MB/s eta 0:00:03
#    -------- ------------------------------- 1.1/5.1 MB 1.8 MB/s eta 0:00:03
#    --------- ------------------------------ 1.2/5.1 MB 1.8 MB/s eta 0:00:03
#    --------- ------------------------------ 1.3/5.1 MB 1.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.3/5.1 MB 1.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.4/5.1 MB 1.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.5/5.1 MB 1.8 MB/s eta 0:00:02
#    ------------ --------------------------- 1.6/5.1 MB 1.8 MB/s eta 0:00:02
#    ------------- -------------------------- 1.7/5.1 MB 1.8 MB/s eta 0:00:02
#    ------------- -------------------------- 1.8/5.1 MB 1.8 MB/s eta 0:00:02
#    -------------- ------------------------- 1.9/5.1 MB 1.8 MB/s eta 0:00:02
#    --------------- ------------------------ 2.0/5.1 MB 1.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.0/5.1 MB 1.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.2/5.1 MB 1.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.3/5.1 MB 1.9 MB/s eta 0:00:02
#    ------------------ --------------------- 2.4/5.1 MB 1.9 MB/s eta 0:00:02
#    ------------------- -------------------- 2.5/5.1 MB 1.9 MB/s eta 0:00:02
#    -------------------- ------------------- 2.6/5.1 MB 1.9 MB/s eta 0:00:02
#    --------------------- ------------------ 2.7/5.1 MB 2.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.8/5.1 MB 2.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.0/5.1 MB 2.0 MB/s eta 0:00:02
#    ------------------------ --------------- 3.1/5.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 3.2/5.1 MB 2.0 MB/s eta 0:00:01
#    -------------------------- ------------- 3.3/5.1 MB 2.0 MB/s eta 0:00:01
#    -------------------------- ------------- 3.4/5.1 MB 2.0 MB/s eta 0:00:01
#    --------------------------- ------------ 3.5/5.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.6/5.1 MB 2.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.7/5.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------ --------- 3.8/5.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 3.9/5.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 4.0/5.1 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 4.1/5.1 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 4.2/5.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.3/5.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.4/5.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.5/5.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 4.7/5.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 4.8/5.1 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 4.9/5.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.1/5.1 MB 2.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.6 MB 3.6 MB/s eta 0:00:03
#     --------------------------------------- 0.2/10.6 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/10.6 MB 2.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/10.6 MB 2.6 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/10.6 MB 2.3 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/10.6 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/10.6 MB 2.2 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/10.6 MB 2.2 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/10.6 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/10.6 MB 2.0 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/10.6 MB 2.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.1/10.6 MB 1.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.2/10.6 MB 2.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.2/10.6 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/10.6 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.4/10.6 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.5/10.6 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.6 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.7/10.6 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/10.6 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 1.9/10.6 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.0/10.6 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/10.6 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.2/10.6 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.3/10.6 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/10.6 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.5/10.6 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.7/10.6 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.8/10.6 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/10.6 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.0/10.6 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.2/10.6 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.3/10.6 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/10.6 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.6/10.6 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.6/10.6 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/10.6 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 3.8/10.6 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/10.6 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 4.0/10.6 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 4.1/10.6 MB 2.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.2/10.6 MB 2.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.4/10.6 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/10.6 MB 2.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.5/10.6 MB 2.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.6/10.6 MB 2.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/10.6 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.8/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.8/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.9/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 5.0/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.1/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.2/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.3/10.6 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.4/10.6 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/10.6 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/10.6 MB 2.0 MB/s eta 0:00:03
#    --------------------- ------------------ 5.7/10.6 MB 2.0 MB/s eta 0:00:03
#    --------------------- ------------------ 5.8/10.6 MB 2.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.9/10.6 MB 2.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.0/10.6 MB 2.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.1/10.6 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.2/10.6 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.3/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 6.4/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 6.5/10.6 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 6.6/10.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------- -------------- 6.7/10.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------- -------------- 6.8/10.6 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 6.9/10.6 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 7.0/10.6 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.6 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 7.2/10.6 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 7.3/10.6 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 7.4/10.6 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.5/10.6 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.7/10.6 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.8/10.6 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.9/10.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 8.0/10.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 8.1/10.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------------- -------- 8.2/10.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------------- -------- 8.4/10.6 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 8.5/10.6 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 8.6/10.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.6 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 9.0/10.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.1/10.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.3/10.6 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.5/10.6 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.6/10.6 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.6 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.9/10.6 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.1/10.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.1/10.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.2/10.6 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 2.0 MB/s eta 0:00:00
# Downloading xarray_beam-0.6.3-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#    ---------------------------------------- 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Downloading zarr-2.17.2-py3-none-any.whl (208 kB)
#    ---------------------------------------- 0.0/208.5 kB ? eta -:--:--
#    ----------------- ---------------------- 92.2/208.5 kB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 194.6/208.5 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 208.5/208.5 kB 1.8 MB/s eta 0:00:00
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading fastavro-1.9.4-cp311-cp311-win_amd64.whl (499 kB)
#    ---------------------------------------- 0.0/499.4 kB ? eta -:--:--
#    ------- -------------------------------- 92.2/499.4 kB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 225.3/499.4 kB 2.3 MB/s eta 0:00:01
#    --------------------------- ------------ 348.2/499.4 kB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 471.0/499.4 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 499.4/499.4 kB 2.1 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading grpcio-1.62.2-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    - -------------------------------------- 0.1/3.8 MB 3.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/3.8 MB 2.5 MB/s eta 0:00:02
#    --- ------------------------------------ 0.3/3.8 MB 2.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.4/3.8 MB 2.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.5/3.8 MB 2.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.6/3.8 MB 2.0 MB/s eta 0:00:02
#    ------ --------------------------------- 0.6/3.8 MB 2.0 MB/s eta 0:00:02
#    ------- -------------------------------- 0.7/3.8 MB 2.0 MB/s eta 0:00:02
#    -------- ------------------------------- 0.8/3.8 MB 1.9 MB/s eta 0:00:02
#    --------- ------------------------------ 0.9/3.8 MB 1.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/3.8 MB 1.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.1/3.8 MB 1.9 MB/s eta 0:00:02
#    ------------ --------------------------- 1.2/3.8 MB 1.9 MB/s eta 0:00:02
#    ------------- -------------------------- 1.2/3.8 MB 1.9 MB/s eta 0:00:02
#    -------------- ------------------------- 1.4/3.8 MB 2.0 MB/s eta 0:00:02
#    --------------- ------------------------ 1.5/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.8 MB 2.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.7/3.8 MB 2.0 MB/s eta 0:00:02
#    ------------------ --------------------- 1.7/3.8 MB 2.0 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/3.8 MB 1.9 MB/s eta 0:00:02
#    ------------------- -------------------- 1.9/3.8 MB 1.9 MB/s eta 0:00:02
#    -------------------- ------------------- 1.9/3.8 MB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 2.0/3.8 MB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/3.8 MB 1.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.2/3.8 MB 1.8 MB/s eta 0:00:01
#    ------------------------ --------------- 2.3/3.8 MB 1.8 MB/s eta 0:00:01
#    -------------------------- ------------- 2.5/3.8 MB 1.8 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.8 MB 1.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.8/3.8 MB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 1.9 MB/s eta 0:00:01
#    ------------------------------- -------- 3.0/3.8 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 1.9 MB/s eta 0:00:01
#    --------------------------------- ------ 3.2/3.8 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.3/3.8 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 3.4/3.8 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 3.5/3.8 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 3.6/3.8 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.8 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 1.9 MB/s eta 0:00:00
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#    ---------------------------------------- 96.9/96.9 kB 5.4 MB/s eta 0:00:00
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    ------------------- -------------------- 143.4/301.2 kB 2.8 MB/s eta 0:00:01
#    ------------------------------- -------- 235.5/301.2 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 301.2/301.2 kB 2.1 MB/s eta 0:00:00
# Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.0 MB 2.0 MB/s eta 0:00:01
#    ------ --------------------------------- 0.2/1.0 MB 2.1 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.0 MB 2.0 MB/s eta 0:00:01
#    ------------- -------------------------- 0.4/1.0 MB 2.0 MB/s eta 0:00:01
#    ------------------ --------------------- 0.5/1.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.6/1.0 MB 2.0 MB/s eta 0:00:01
#    --------------------------- ------------ 0.7/1.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.1 MB/s eta 0:00:00
# Downloading jsonpickle-3.0.4-py3-none-any.whl (39 kB)
# Downloading numcodecs-0.12.1-cp311-cp311-win_amd64.whl (790 kB)
#    ---------------------------------------- 0.0/790.3 kB ? eta -:--:--
#    ----- ---------------------------------- 102.4/790.3 kB 3.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 204.8/790.3 kB 2.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 337.9/790.3 kB 2.6 MB/s eta 0:00:01
#    -------------------- ------------------- 399.4/790.3 kB 2.3 MB/s eta 0:00:01
#    -------------------------- ------------- 532.5/790.3 kB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 593.9/790.3 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 675.8/790.3 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  778.2/790.3 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 790.3/790.3 kB 2.0 MB/s eta 0:00:00
# Downloading objsize-0.7.0-py3-none-any.whl (11 kB)
# Downloading orjson-3.10.1-cp311-none-win_amd64.whl (139 kB)
#    ---------------------------------------- 0.0/139.1 kB ? eta -:--:--
#    -------------------- ------------------- 71.7/139.1 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 139.1/139.1 kB 1.7 MB/s eta 0:00:00
# Using cached proto_plus-1.23.0-py3-none-any.whl (48 kB)
# Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
# Downloading pyarrow-11.0.0-cp311-cp311-win_amd64.whl (20.5 MB)
#    ---------------------------------------- 0.0/20.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/20.5 MB 2.6 MB/s eta 0:00:08
#    ---------------------------------------- 0.2/20.5 MB 2.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.3/20.5 MB 2.0 MB/s eta 0:00:11
#     --------------------------------------- 0.4/20.5 MB 2.1 MB/s eta 0:00:10
#     --------------------------------------- 0.5/20.5 MB 2.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.6/20.5 MB 2.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.7/20.5 MB 2.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.8/20.5 MB 2.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.9/20.5 MB 2.2 MB/s eta 0:00:09
#    - -------------------------------------- 1.0/20.5 MB 2.2 MB/s eta 0:00:09
#    -- ------------------------------------- 1.1/20.5 MB 2.2 MB/s eta 0:00:09
#    -- ------------------------------------- 1.2/20.5 MB 2.2 MB/s eta 0:00:09
#    -- ------------------------------------- 1.3/20.5 MB 2.2 MB/s eta 0:00:09
#    -- ------------------------------------- 1.4/20.5 MB 2.2 MB/s eta 0:00:09
#    -- ------------------------------------- 1.5/20.5 MB 2.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.6/20.5 MB 2.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.7/20.5 MB 2.1 MB/s eta 0:00:09
#    --- ------------------------------------ 1.8/20.5 MB 2.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.9/20.5 MB 2.2 MB/s eta 0:00:09
#    --- ------------------------------------ 2.0/20.5 MB 2.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.1/20.5 MB 2.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.2/20.5 MB 2.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.3/20.5 MB 2.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.4/20.5 MB 2.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.5/20.5 MB 2.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 2.6/20.5 MB 2.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 2.7/20.5 MB 2.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 2.9/20.5 MB 2.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.0/20.5 MB 2.2 MB/s eta 0:00:08
#    ------ --------------------------------- 3.1/20.5 MB 2.2 MB/s eta 0:00:08
#    ------ --------------------------------- 3.2/20.5 MB 2.2 MB/s eta 0:00:08
#    ------ --------------------------------- 3.3/20.5 MB 2.2 MB/s eta 0:00:08
#    ------ --------------------------------- 3.4/20.5 MB 2.2 MB/s eta 0:00:08
#    ------ --------------------------------- 3.5/20.5 MB 2.2 MB/s eta 0:00:08
#    ------ --------------------------------- 3.5/20.5 MB 2.2 MB/s eta 0:00:08
#    ------- -------------------------------- 3.6/20.5 MB 2.2 MB/s eta 0:00:08
#    ------- -------------------------------- 3.7/20.5 MB 2.2 MB/s eta 0:00:08
#    ------- -------------------------------- 3.8/20.5 MB 2.2 MB/s eta 0:00:08
#    ------- -------------------------------- 4.0/20.5 MB 2.2 MB/s eta 0:00:08
#    ------- -------------------------------- 4.0/20.5 MB 2.2 MB/s eta 0:00:08
#    -------- ------------------------------- 4.2/20.5 MB 2.2 MB/s eta 0:00:08
#    -------- ------------------------------- 4.3/20.5 MB 2.2 MB/s eta 0:00:08
#    -------- ------------------------------- 4.4/20.5 MB 2.2 MB/s eta 0:00:08
#    -------- ------------------------------- 4.5/20.5 MB 2.2 MB/s eta 0:00:08
#    -------- ------------------------------- 4.6/20.5 MB 2.2 MB/s eta 0:00:08
#    --------- ------------------------------ 4.7/20.5 MB 2.2 MB/s eta 0:00:08
#    --------- ------------------------------ 4.8/20.5 MB 2.2 MB/s eta 0:00:08
#    --------- ------------------------------ 4.9/20.5 MB 2.2 MB/s eta 0:00:08
#    --------- ------------------------------ 5.1/20.5 MB 2.2 MB/s eta 0:00:07
#    --------- ------------------------------ 5.1/20.5 MB 2.2 MB/s eta 0:00:08
#    ---------- ----------------------------- 5.2/20.5 MB 2.2 MB/s eta 0:00:07
# ...
#    ------------------------------- -------- 16.3/20.5 MB 2.1 MB/s eta 0:00:03
#    ------------------------------- -------- 16.3/20.5 MB 2.0 MB/s eta 0:00:03
#    ------------------------------- -------- 16.3/20.5 MB 2.0 MB/s eta 0:00:03
#    -------------------------------- ------- 16.4/20.5 MB 2.0 MB/s eta 0:00:03
#    -------------------------------- ------- 16.5/20.5 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 16.6/20.5 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 16.7/20.5 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 16.8/20.5 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 16.9/20.5 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 17.0/20.5 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 17.1/20.5 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 17.2/20.5 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 17.3/20.5 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 17.4/20.5 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 17.5/20.5 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 17.6/20.5 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 17.7/20.5 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 17.8/20.5 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 17.9/20.5 MB 2.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 18.0/20.5 MB 2.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 18.1/20.5 MB 2.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 18.2/20.5 MB 2.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 18.3/20.5 MB 2.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 18.4/20.5 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------ --- 18.5/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 18.6/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 18.7/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 18.8/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 18.9/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 19.0/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 19.1/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 19.2/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 19.3/20.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 19.4/20.5 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 19.5/20.5 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 19.7/20.5 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 19.8/20.5 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 19.9/20.5 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 20.0/20.5 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  20.1/20.5 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.5 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  20.3/20.5 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  20.4/20.5 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  20.5/20.5 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 20.5/20.5 MB 2.1 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Downloading pymongo-4.7.0-cp311-cp311-win_amd64.whl (484 kB)
#    ---------------------------------------- 0.0/484.7 kB ? eta -:--:--
#    ------- -------------------------------- 92.2/484.7 kB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 225.3/484.7 kB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 399.4/484.7 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 484.7/484.7 kB 2.0 MB/s eta 0:00:00
# Downloading rechunker-0.5.2-py3-none-any.whl (22 kB)
# Downloading regex-2024.4.16-cp311-cp311-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.9 kB ? eta -:--:--
#    ---------- ----------------------------- 71.7/268.9 kB 2.0 MB/s eta 0:00:01
#    --------------------------- ------------ 184.3/268.9 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 268.9/268.9 kB 2.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Downloading zstandard-0.22.0-cp311-cp311-win_amd64.whl (511 kB)
#    ---------------------------------------- 0.0/511.6 kB ? eta -:--:--
#    -------- ------------------------------- 102.4/511.6 kB 2.9 MB/s eta 0:00:01
#    -------------- ------------------------- 184.3/511.6 kB 2.2 MB/s eta 0:00:01
#    -------------------- ------------------- 266.2/511.6 kB 2.0 MB/s eta 0:00:01
#    -------------------------- ------------- 337.9/511.6 kB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 471.0/511.6 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 511.6/511.6 kB 2.0 MB/s eta 0:00:00
# Downloading immutabledict-4.2.0-py3-none-any.whl (4.7 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/307.7 kB 991.0 kB/s eta 0:00:01
#    ---------------------- ----------------- 174.1/307.7 kB 1.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 225.3/307.7 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 307.7/307.7 kB 1.5 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading bokeh-3.4.1-py3-none-any.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.0 MB 2.6 MB/s eta 0:00:03
#     --------------------------------------- 0.2/7.0 MB 2.1 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/7.0 MB 2.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.4/7.0 MB 2.1 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/7.0 MB 2.1 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/7.0 MB 2.0 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/7.0 MB 2.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.8/7.0 MB 2.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.9/7.0 MB 2.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.0 MB 2.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.1/7.0 MB 2.2 MB/s eta 0:00:03
#    ------- -------------------------------- 1.2/7.0 MB 2.2 MB/s eta 0:00:03
#    ------- -------------------------------- 1.4/7.0 MB 2.2 MB/s eta 0:00:03
#    -------- ------------------------------- 1.5/7.0 MB 2.2 MB/s eta 0:00:03
#    --------- ------------------------------ 1.6/7.0 MB 2.3 MB/s eta 0:00:03
#    --------- ------------------------------ 1.6/7.0 MB 2.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.8/7.0 MB 2.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.9/7.0 MB 2.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.0/7.0 MB 2.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.1/7.0 MB 2.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.2/7.0 MB 2.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.3/7.0 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.0 MB 2.2 MB/s eta 0:00:03
#    -------------- ------------------------- 2.5/7.0 MB 2.2 MB/s eta 0:00:03
#    -------------- ------------------------- 2.6/7.0 MB 2.2 MB/s eta 0:00:03
#    --------------- ------------------------ 2.7/7.0 MB 2.2 MB/s eta 0:00:02
#    --------------- ------------------------ 2.8/7.0 MB 2.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.8/7.0 MB 2.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.9/7.0 MB 2.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.0/7.0 MB 2.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------ --------------------- 3.2/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------ --------------------- 3.3/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------- -------------------- 3.4/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------- -------------------- 3.5/7.0 MB 2.1 MB/s eta 0:00:02
#    -------------------- ------------------- 3.6/7.0 MB 2.1 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.0 MB 2.1 MB/s eta 0:00:02
#    --------------------- ------------------ 3.8/7.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.9/7.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.0/7.0 MB 2.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.1/7.0 MB 2.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.2/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 4.3/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 4.4/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 4.4/7.0 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 4.5/7.0 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 4.6/7.0 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 4.8/7.0 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 4.9/7.0 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.1/7.0 MB 2.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------ --------- 5.3/7.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------ --------- 5.4/7.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/7.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 5.6/7.0 MB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.7/7.0 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/7.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.1/7.0 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.2/7.0 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 6.4/7.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 6.5/7.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.7/7.0 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  6.9/7.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 2.1 MB/s eta 0:00:00
# Downloading xyzservices-2024.4.0-py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#    ---------------------------------------  81.9/82.0 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 82.0/82.0 kB 1.5 MB/s eta 0:00:00
# Building wheels for collected packages: weatherbench2, crcmod, dill, hdfs, asciitree, pyjsparser, docopt
#   Building wheel for weatherbench2 (pyproject.toml): started
#   Building wheel for weatherbench2 (pyproject.toml): finished with status 'done'
#   Created wheel for weatherbench2: filename=weatherbench2-0.2.0-py3-none-any.whl size=71902 sha256=7db23fc4fac22b366e007db27958513a9dfafaa5bc1a05ba809e62d979c17d13
#   Stored in directory: C:\Users\lukas\AppData\Local\Temp\pip-ephem-wheel-cache-nqjl0u0z\wheels\50\b4\e3\20d374028ee61e1c8af9626d7a5ff2d4cb3d1612e557b35cb4
#   Building wheel for crcmod (setup.py): started
#   Building wheel for crcmod (setup.py): finished with status 'done'
#   Created wheel for crcmod: filename=crcmod-1.7-cp311-cp311-win_amd64.whl size=25151 sha256=a8ef0b8eb8b4b05dc2be828952c9ac57a3440ff0a105b70b344d62899a65cca6
#   Stored in directory: c:\users\lukas\appdata\local\pip\cache\wheels\23\94\7a\8cb7d14597e6395ce969933f01aed9ea8fa5f5b4d4c8a61e99
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78667 sha256=1ab35ba0612ec965de27e90d75fa511f68569240b7d6da2f82df19530c9cee84
#   Stored in directory: c:\users\lukas\appdata\local\pip\cache\wheels\01\60\80\1622338bcecce31a5664ef01c203cc5a7b09f59588d9c07376
#   Building wheel for hdfs (setup.py): started
#   Building wheel for hdfs (setup.py): finished with status 'done'
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34350 sha256=407922cbef55d726d7df45768877b9eb27ba78224f0904a155cab2e62cf78d90
#   Stored in directory: c:\users\lukas\appdata\local\pip\cache\wheels\b9\1d\dc\eb0833be25464c359903d356c4204721c6a672c26ff164cdc3
#   Building wheel for asciitree (setup.py): started
#   Building wheel for asciitree (setup.py): finished with status 'done'
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5047 sha256=5f4600e776951edc3a8830c5bd172108786fb5bbddf849b4596f1c7513826756
#   Stored in directory: c:\users\lukas\appdata\local\pip\cache\wheels\71\c1\da\23077eb3b87d24d6f3852ed1ed1a1ac2d3c885ad6ebd2b4a07
#   Building wheel for pyjsparser (setup.py): started
#   Building wheel for pyjsparser (setup.py): finished with status 'done'
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25988 sha256=e18b06020f100eac65b77638ca1370ba8610ab5fddbab698fb70c055f4e3185d
#   Stored in directory: c:\users\lukas\appdata\local\pip\cache\wheels\a5\9a\30\1003e89ab4555b81840ca46d361bf184f1e6ad880cae3b62a9
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13773 sha256=45f7656fc81f05d817ca98a9016c1815b000d12de059064c0ac6d9e6196bc6cc
#   Stored in directory: c:\users\lukas\appdata\local\pip\cache\wheels\1a\b0\8c\4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built weatherbench2 crcmod dill hdfs asciitree pyjsparser docopt
# Installing collected packages: pyjsparser, docopt, crcmod, asciitree, zstandard, xyzservices, tzlocal, threadpoolctl, regex, pydot, pyarrow-hotfix, pyarrow, protobuf, orjson, objsize, numcodecs, mypy-extensions, jsonpickle, joblib, immutabledict, httplib2, grpcio, fasteners, fastavro, dnspython, dill, cloudpickle, zarr, scikit-learn, pymongo, proto-plus, pandas, js2py, hdfs, xarray, bokeh, apache-beam, rechunker, xarray-beam, weatherbench2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.26.1
#     Uninstalling protobuf-5.26.1:
#       Successfully uninstalled protobuf-5.26.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.0.0
#     Uninstalling cloudpickle-3.0.0:
#       Successfully uninstalled cloudpickle-3.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/weatherbench2.git 'C:\Users\lukas\AppData\Local\Temp\pip-req-build-nx0j_vv6'
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\lukas\\anaconda3\\envs\\mtlmenv\\lib\\site-packages\\pandas\\_libs\\algos.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
#import apache_beam   # Needs to be imported separately to avoid TypingError
import weatherbench2

# %% [markdown]
# # Specify input datasets
# !! need to download the data from the bucket using google colab, before it can be used.

# %%
# empty for now.
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 storage_client = storage.Client()
# ----> 2 bucket = storage_client.get_bucket('weatherbench2')
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\cloud\storage\client.py:857, in Client.get_bucket(self, bucket_or_name, timeout, if_metageneration_match, if_metageneration_not_match, retry)
#     809 """Retrieve a bucket via a GET request.
#     810
#     811 See [API reference docs](https://cloud.google.com/storage/docs/json_api/v1/buckets/get) and a [code sample](https://cloud.google.com/storage/docs/samples/storage-get-bucket-metadata#storage_get_bucket_metadata-python).
#    (...)
#     854         If the bucket is not found.
#     855 """
#     856 bucket = self._bucket_arg_to_bucket(bucket_or_name)
# --> 857 bucket.reload(
#     858     client=self,
#     859     timeout=timeout,
#     860     if_metageneration_match=if_metageneration_match,
#     861     if_metageneration_not_match=if_metageneration_not_match,
#     862     retry=retry,
#     863 )
#     864 return bucket
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\cloud\storage\bucket.py:1083, in Bucket.reload(self, client, projection, timeout, if_etag_match, if_etag_not_match, if_metageneration_match, if_metageneration_not_match, retry)
#    1033 def reload(
#    1034     self,
#    1035     client=None,
#    (...)
#    1042     retry=DEFAULT_RETRY,
#    1043 ):
#    1044     """Reload properties from Cloud Storage.
#    1045
#    1046     If :attr:`user_project` is set, bills the API request to that project.
#    (...)
#    1081         (Optional) How to retry the RPC. See: :ref:`configuring_retries`
#    1082     """
# -> 1083     super(Bucket, self).reload(
#    1084         client=client,
#    1085         projection=projection,
#    1086         timeout=timeout,
#    1087         if_etag_match=if_etag_match,
#    1088         if_etag_not_match=if_etag_not_match,
#    1089         if_metageneration_match=if_metageneration_match,
#    1090         if_metageneration_not_match=if_metageneration_not_match,
#    1091         retry=retry,
#    1092     )
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\cloud\storage\_helpers.py:300, in _PropertyMixin.reload(self, client, projection, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, retry, soft_deleted)
#     296 headers = self._encryption_headers()
#     297 _add_etag_match_headers(
#     298     headers, if_etag_match=if_etag_match, if_etag_not_match=if_etag_not_match
#     299 )
# --> 300 api_response = client._get_resource(
#     301     self.path,
#     302     query_params=query_params,
#     303     headers=headers,
#     304     timeout=timeout,
#     305     retry=retry,
#     306     _target_object=self,
#     307 )
#     308 self._set_properties(api_response)
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\cloud\storage\client.py:462, in Client._get_resource(self, path, query_params, headers, timeout, retry, _target_object)
#     406 def _get_resource(
#     407     self,
#     408     path,
#    (...)
#     413     _target_object=None,
#     414 ):
#     415     """Helper for bucket / blob methods making API 'GET' calls.
#     416
#     417     Args:
#    (...)
#     460             If the bucket is not found.
#     461     """
# --> 462     return self._connection.api_request(
#     463         method="GET",
#     464         path=path,
#     465         query_params=query_params,
#     466         headers=headers,
#     467         timeout=timeout,
#     468         retry=retry,
#     469         _target_object=_target_object,
#     470     )
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\cloud\storage\_http.py:78, in Connection.api_request(self, *args, **kwargs)
#      76     if retry:
#      77         call = retry(call)
# ---> 78 return call()
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\Documents\UA\II-Master project\Thesis_project\.venv\Lib\site-packages\google\cloud\_http\__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#    (...)
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#     497     return response.json()
#
# Forbidden: 403 GET https://storage.googleapis.com/storage/v1/b/weatherbench2?projection=noAcl&prettyPrint=false: lukas-494@resonant-sunset-420111.iam.gserviceaccount.com does not have storage.buckets.get access to the Google Cloud Storage bucket. Permission 'storage.buckets.get' denied on resource (or it may not exist).

# %% [markdown]
# ### Set up WeatherBench configuration
#
# Next, we will define a bunch of configuration instances to specify exactly what we want to evaluate.

# %%
from weatherbench2 import config
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from weatherbench2 import config
#
# File ~\Documents\UA\II-Master project\Masters-Thesis\weatherbench2\config.py:20
#      17 import dataclasses
#      18 import typing as t
# ---> 20 from weatherbench2.derived_variables import DerivedVariable
#      21 from weatherbench2.metrics import Metric
#      22 from weatherbench2.regions import ExtraTropicalRegion
#
# File ~\Documents\UA\II-Master project\Masters-Thesis\weatherbench2\derived_variables.py:22
#      20 import numpy as np
#      21 import scipy.integrate
# ---> 22 from weatherbench2 import schema
#      23 import xarray as xr
#      26 # pylint: disable=invalid-name
#
# File ~\Documents\UA\II-Master project\Masters-Thesis\weatherbench2\schema.py:21
#      19 import numpy as np
#      20 import numpy.typing as npt
# ---> 21 import pandas as pd
#      22 import xarray
#      25 def apply_time_conventions(
#      26     forecast: xarray.Dataset, by_init: bool
#      27 ) -> xarray.Dataset:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\__init__.py:151
#     132 from pandas.core.computation.api import eval
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)
#     148     qcut,
#     149 )
# --> 151 from pandas import api, arrays, errors, io, plotting, tseries
#     152 from pandas import testing
#     153 from pandas.util._print_versions import show_versions
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File ~\anaconda3\envs\MTLMenv\Lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File ~\anaconda3\envs\MTLMenv\Lib\site-packages\pandas\io\json\_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File ~\anaconda3\envs\MTLMenv\Lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File ~\anaconda3\envs\MTLMenv\Lib\site-packages\pandas\io\parsers\readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %% [markdown]
# # data configuration
# The file paths are defined in a Paths config object, alongside an output directory:

# %%
paths = config.Paths(
    forecast=forecast_path,
    obs=obs_path,
    output_dir='./',   # Directory to save evaluation results
)

# %% [markdown]
# In addition, we specify a Selection object that selects the variables and time period to be evaluated.

# %%
selection = config.Selection(
    variables=[
        'geopotential',
        '2m_temperature'
    ],
    levels=[500, 700, 850],
    time_slice=slice('2020-01-01', '2020-12-31'),
)

# %% [markdown]
# Together they make up the Data config:

# %%
data_config = config.Data(selection=selection, paths=paths)

# %% [markdown]
# #### Evaluation configuration
#
# Next, we can defined which evaluation we want to run. To do so, we can define a dictionary of `config.Eval`s, each of which will be evaluated separately and saved to a different file. Eval instances contain the metrics objects, defined in metrics.py.
#
# Note that for ACC, we additionally need to pass the climatology opened earlier.

# %% [markdown]
# from weatherbench2.metrics import MSE, ACC
#
# eval_configs = {
#   'deterministic': config.Eval(
#       metrics={
#           'mse': MSE(),
#           'acc': ACC(climatology=climatology)
#       },
#   )
# }

# %% [markdown]
# The evaluation configs also have an option to evaluate particular regions, such as a geographical lat-lon box. These are defined as region objects defined in regions.py. All regions will be evaluated separately and saved as an additional dimension in the dataset. If no region is specified, evaluation will be done globally.

# %%
from weatherbench2.regions import SliceRegion, ExtraTropicalRegion

regions = {
    'global': SliceRegion(),
    'tropics': SliceRegion(lat_slice=slice(-20, 20)),
    'extra-tropics': ExtraTropicalRegion(),
}

eval_configs = {
  'deterministic': config.Eval(
      metrics={
          'mse': MSE(), 
          'acc': ACC(climatology=climatology) 
      },
      regions=regions
  )
}

# %% [markdown]
# ### Evaluate
#
# Now, we are already done and can run the evaluation. We can do so in memory for smaller datasets or as a Beam pipeline (recommended for anything larger than 64x32 resolution).

# %%
from weatherbench2.evaluation import evaluate_in_memory

# %%
evaluate_in_memory(data_config, eval_configs)   # Takes around 5 minutes

# %% [markdown]
# ### Results
# Results are saved as NetCDF files under the name of the eval config.

# %%
results = xr.open_dataset('./deterministic.nc')
results

# %% [markdown]
# Note that to compute the RMSE, we follow ECMWF's convention by taking the square root after the time mean. To do this in WB2, first compute the MSE and then take the square root of the saved MSE results

# %%
results = xr.concat(
    [
    results,
    results.sel(metric=['mse']).assign_coords(metric=['rmse']) ** 0.5
    ],
    dim='metric'
)

# %%
results['geopotential'].sel(metric='rmse', level=500, region='global').plot();
